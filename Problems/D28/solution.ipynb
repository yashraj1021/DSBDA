# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('../admission_data.csv')
df.head()
# Out:
#    GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 0        337          118                  4  4.5   4.5  9.65         1  \
# 1        324          107                  4  4.0   4.5  8.87         1
# 2        316          104                  3  3.0   3.5  8.00         1
# 3        322          110                  3  3.5   2.5  8.67         1
# 4        314          103                  2  2.0   3.0  8.21         0
#
#    Chance of Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df.shape
# Out:
# (303, 14)

# %%
plt.hist(df['Chance of Admit '],bins=10,edgecolor='black')
# Out:
# (array([ 8., 16., 24., 47., 63., 78., 93., 62., 48., 61.]),
#  array([0.34 , 0.403, 0.466, 0.529, 0.592, 0.655, 0.718, 0.781, 0.844,
#         0.907, 0.97 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['GRE Score'],df['Chance of Admit '],marker='o')
plt.show()

# %%
plt.bar(df['University Rating'],df['Chance of Admit '],color='red')
# Out:
# <BarContainer object of 500 artists>

# %%
plt.plot(df['GRE Score'],df['Chance of Admit '])

# %%
level={5:5,1:1,2:2,3:3,4:4}
mapp=[level[numm] for numm in df['University Rating']]

plt.scatter(df['GRE Score'],df['Chance of Admit '],c=mapp,cmap='viridis')
cbar=plt.colorbar()
cbar.set_label('level')
