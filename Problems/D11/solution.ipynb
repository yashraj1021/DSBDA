# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../movies_metadata.csv')
df.head()
# Out:
# C:\Users\Atul Maharnawar\AppData\Local\Temp\ipykernel_7556\624024062.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...  \
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df['original_language'].unique()
# Out:
# array(['en', 'fr', 'zh', 'it', 'fa', 'nl', 'de', 'cn', 'ar', 'es', 'ru',
#        'sv', 'ja', 'ko', 'sr', 'bn', 'he', 'pt', 'wo', 'ro', 'hu', 'cy',
#        'vi', 'cs', 'da', 'no', 'nb', 'pl', 'el', 'sh', 'xx', 'mk', 'bo',
#        'ca', 'fi', 'th', 'sk', 'bs', 'hi', 'tr', 'is', 'ps', 'ab', 'eo',
#        'ka', 'mn', 'bm', 'zu', 'uk', 'af', 'la', 'et', 'ku', 'fy', 'lv',
#        'ta', 'sl', 'tl', 'ur', 'rw', 'id', 'bg', 'mr', 'lt', 'kk', 'ms',
#        'sq', nan, '104.0', 'qu', 'te', 'am', 'jv', 'tg', 'ml', 'hr', 'lo',
#        'ay', 'kn', 'eu', 'ne', 'pa', 'ky', 'gl', '68.0', 'uz', 'sm', 'mt',
#        '82.0', 'hy', 'iu', 'lb', 'si'], dtype=object)

# %%
subset1=df[df['original_language']=='en']
subset1
# Out:
#        adult                              belongs_to_collection    budget
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45459  False                                                NaN         0
# 45460  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres
# ...

# %%
subset2=df[df['original_language']=='fr']
subset2
# Out:
#        adult belongs_to_collection    budget
# 28     False                   NaN  18000000  \
# 32     False                   NaN         0
# 58     False                   NaN         0
# 67     False                   NaN         0
# 72     False                   NaN         0
# ...      ...                   ...       ...
# 45444  False                   NaN         0
# 45447  False                   NaN         0
# 45448  False                   NaN         0
# 45450  False                   NaN         0
# 45451  False                   NaN         0
#
#                                                   genres homepage      id
# 28     [{'id': 14, 'name': 'Fantasy'}, {'id': 878, 'n...      NaN     902  \
# 32     [{'id': 10749, 'name': 'Romance'}, {'id': 12, ...      NaN   78802
# 58     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...      NaN   99040
# 67     [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...      NaN    4482
# ...

# %%
df2=pd.concat([subset1,subset2]).sort_index()
df2
# Out:
#        adult                              belongs_to_collection    budget
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000  \
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45459  False                                                NaN         0
# 45460  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres
# ...

# %%
df3=df.sort_values('vote_average',ascending=False)
df3
# Out:
#                                                    adult
# 21642                                              False  \
# 15710                                              False
# 22396                                              False
# 22395                                              False
# 35343                                              False
# ...                                                  ...
# 19730                                 - Written by Ørnås
# 29502                                              False
# 29503   Rune Balot goes to a casino connected to the ...
# 35586                                              False
# 35587   Avalanche Sharks tells the story of a bikini ...
#
#                                    belongs_to_collection
# 21642                                                NaN  \
# 15710                                                NaN
# 22396                                                NaN
# ...

# %%
df4=df[['id','original_language','vote_average','vote_count']]

# %%
df4=df4.dropna()
df4
# Out:
#            id original_language  vote_average  vote_count
# 9         710                en           6.6      1194.0
# 68      10634                en           7.0       513.0
# 69        755                en           6.9      1644.0
# 153      5894                en           6.8        28.0
# 178      9070                en           5.2       153.0
# ...       ...               ...           ...         ...
# 44274  281338                en           6.7      1675.0
# 44674  336890                en           6.0        35.0
# 44821   10991                ja           6.0       144.0
# 44842  335988                en           6.2      1440.0
# 45029  417489                fr           6.8         5.0
#
# [693 rows x 4 columns]

# %%
df5=df4.melt(id_vars=['id'],var_name='rating',value_name='rate_val')
df5
# Out:
#           id             rating rate_val
# 0        710  original_language       en
# 1      10634  original_language       en
# 2        755  original_language       en
# 3       5894  original_language       en
# 4       9070  original_language       en
# ...      ...                ...      ...
# 2074  281338         vote_count   1675.0
# 2075  336890         vote_count     35.0
# 2076   10991         vote_count    144.0
# 2077  335988         vote_count   1440.0
# 2078  417489         vote_count      5.0
#
# [2079 rows x 3 columns]

# %%
df6=pd.pivot_table(df4,index=['original_language'])
df6.shape
df6
# Out:
#                                                                   id
# original_language
# ar                                                          215407.0  \
# cn                                    1405173152459395957826519040.0
# da                                             68716249416465.664062
# de                                                    104616138983.5
# en                                                               inf
# es                                            20822766620070047744.0
# fi                                                      2419779382.0
# fr                                              334862289472496.3125
# hi                        5290393425646876168151196116021680275456.0
# id                                                     47164590149.5
# it                                                        21470525.0
# ja                 4344520660853755841962475576018229382963979994...
# ...
