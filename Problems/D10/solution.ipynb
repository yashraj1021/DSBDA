# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../Iris.csv')
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
subset1=df[df['Species']=='Iris-setosa']
subset2=df[df['Species']=='Iris-versicolor']
subset3=df[df['Species']=='Iris-virginica']

# %%
subset1
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
subset2
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 50   51            7.0           3.2            4.7           1.4  \
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
subset3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 100  101            6.3           3.3            6.0           2.5  \
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
df1=pd.concat([subset1,subset2]).sort_index()
df1
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0     1            5.1           3.5            1.4           0.2  \
# 1     2            4.9           3.0            1.4           0.2
# 2     3            4.7           3.2            1.3           0.2
# 3     4            4.6           3.1            1.5           0.2
# 4     5            5.0           3.6            1.4           0.2
# ..  ...            ...           ...            ...           ...
# 95   96            5.7           3.0            4.2           1.2
# 96   97            5.7           2.9            4.2           1.3
# 97   98            6.2           2.9            4.3           1.3
# 98   99            5.1           2.5            3.0           1.1
# 99  100            5.7           2.8            4.1           1.3
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 95  Iris-versicolor
# ...

# %%
df3=df.sort_values('PetalLengthCm',ascending=True)
df3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 22    23            4.6           3.6            1.0           0.2  \
# 13    14            4.3           3.0            1.1           0.1
# 14    15            5.8           4.0            1.2           0.2
# 35    36            5.0           3.2            1.2           0.2
# 36    37            5.5           3.5            1.3           0.2
# ..   ...            ...           ...            ...           ...
# 131  132            7.9           3.8            6.4           2.0
# 105  106            7.6           3.0            6.6           2.1
# 117  118            7.7           3.8            6.7           2.2
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
#
#             Species
# 22      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 35      Iris-setosa
# 36      Iris-setosa
# ..              ...
# ...

# %%
df4=df.transpose()
df4
# Out:
#                        0            1            2            3
# Id                       1            2            3            4  \
# SepalLengthCm          5.1          4.9          4.7          4.6
# SepalWidthCm           3.5          3.0          3.2          3.1
# PetalLengthCm          1.4          1.4          1.3          1.5
# PetalWidthCm           0.2          0.2          0.2          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
#                        4            5            6            7
# Id                       5            6            7            8  \
# SepalLengthCm          5.0          5.4          4.6          5.0
# SepalWidthCm           3.6          3.9          3.4          3.4
# PetalLengthCm          1.4          1.7          1.4          1.5
# PetalWidthCm           0.2          0.4          0.3          0.2
# Species        Iris-setosa  Iris-setosa  Iris-setosa  Iris-setosa
#
# ...

# %%
df_melt=pd.melt(df,id_vars=['Id','Species'],var_name='measurement',value_name='size')
df_melt
# Out:
#       Id         Species    measurement  size
# 0      1     Iris-setosa  SepalLengthCm   5.1
# 1      2     Iris-setosa  SepalLengthCm   4.9
# 2      3     Iris-setosa  SepalLengthCm   4.7
# 3      4     Iris-setosa  SepalLengthCm   4.6
# 4      5     Iris-setosa  SepalLengthCm   5.0
# ..   ...             ...            ...   ...
# 595  146  Iris-virginica   PetalWidthCm   2.3
# 596  147  Iris-virginica   PetalWidthCm   1.9
# 597  148  Iris-virginica   PetalWidthCm   2.0
# 598  149  Iris-virginica   PetalWidthCm   2.3
# 599  150  Iris-virginica   PetalWidthCm   1.8
#
# [600 rows x 4 columns]

# %%
df_cast=pd.pivot_table(df_melt,index=['Id','Species'],columns='measurement',values='size')
df_cast
# Out:
# measurement         PetalLengthCm  PetalWidthCm  SepalLengthCm  SepalWidthCm
# Id  Species
# 1   Iris-setosa               1.4           0.2            5.1           3.5
# 2   Iris-setosa               1.4           0.2            4.9           3.0
# 3   Iris-setosa               1.3           0.2            4.7           3.2
# 4   Iris-setosa               1.5           0.2            4.6           3.1
# 5   Iris-setosa               1.4           0.2            5.0           3.6
# ...                           ...           ...            ...           ...
# 146 Iris-virginica            5.2           2.3            6.7           3.0
# 147 Iris-virginica            5.0           1.9            6.3           2.5
# 148 Iris-virginica            5.2           2.0            6.5           3.0
# 149 Iris-virginica            5.4           2.3            6.2           3.4
# 150 Iris-virginica            5.1           1.8            5.9           3.0
#
# [150 rows x 4 columns]
