# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('../Cleavland.csv')
df.head()
# Out:
#     Age  Sex   cp  trestbps   chol  fbs  restecg  thalac  exang  oldpeak
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0   150.0    0.0      2.3  \
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0   108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0   129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0   187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0   172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df.shape
# Out:
# (303, 14)

# %%
plt.hist(df['num'],bins=10,edgecolor='black')
# Out:
# (array([164.,   0.,  55.,   0.,   0.,  36.,   0.,  35.,   0.,  13.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(df['trestbps'],df['Age'],marker='o')
plt.show()

# %%
plt.bar(df['Age'],df['ca'],color='red')
# Out:
# <BarContainer object of 303 artists>

# %%
plt.plot(df['Age'],df['num'])

# %%
level={0:0,1:1,2:2,3:3,4:4}
mapp=[level[numm] for numm in df['num']]

plt.scatter(df['Age'],df['thalac'],c=mapp,cmap='viridis')
cbar=plt.colorbar()
cbar.set_label('level')
