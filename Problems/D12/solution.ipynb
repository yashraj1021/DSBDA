# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('../AdultData.csv')
df.head()
# Out:
#    Age          Workclass      Id   Education       Marital-Status
# 0   39          State-gov   77516   Bachelors        Never-married  \
# 1   50   Self-emp-not-inc   83311   Bachelors   Married-civ-spouse
# 2   38            Private  215646     HS-grad             Divorced
# 3   53            Private  234721        11th   Married-civ-spouse
# 4   28            Private  338409   Bachelors   Married-civ-spouse
#
#            Occupation      Unnamed: 6    Race      Sex  Native-Country  Salary
# 0        Adm-clerical   Not-in-family   White     Male   United-States   <=50K
# 1     Exec-managerial         Husband   White     Male   United-States   <=50K
# 2   Handlers-cleaners   Not-in-family   White     Male   United-States   <=50K
# 3   Handlers-cleaners         Husband   Black     Male   United-States   <=50K
# 4      Prof-specialty            Wife   Black   Female            Cuba   <=50K

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Id', 'Education', 'Marital-Status', 'Occupation',
#        'Unnamed: 6', 'Race', 'Sex', 'Native-Country', 'Salary'],
#       dtype='object')

# %%
df.shape
# Out:
# (32561, 11)

# %%
df['Native-Country'].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
subset1=df[df['Native-Country']==' India']
subset2=df[df['Race']=='White']
subset3=df[df['Sex']=='Male']

# %%
df2=pd.concat([subset1,subset2])
df2
# Out:
#        Age          Workclass      Id    Education          Marital-Status
# 11      30          State-gov  141297    Bachelors      Married-civ-spouse  \
# 892     28            Private  164170    Assoc-voc      Married-civ-spouse
# 968     48            Private  164966    Bachelors      Married-civ-spouse
# 1029    48       Self-emp-inc  138370      Masters   Married-spouse-absent
# 1095    22   Self-emp-not-inc  361280    Bachelors           Never-married
# ...    ...                ...     ...          ...                     ...
# 30152   48            Private  119471    Doctorate      Married-civ-spouse
# 30833   25            Private  110978   Assoc-acdm      Married-civ-spouse
# 30871   26            Private  160261      Masters           Never-married
# 31327   38          State-gov  125499    Bachelors      Married-civ-spouse
# 31357   23            Private  143003      Masters      Married-civ-spouse
#
# ...

# %%
df3=df.transpose()
df3
# Out:
#                          0                    1                   2
# Age                         39                   50                  38  \
# Workclass            State-gov     Self-emp-not-inc             Private
# Id                       77516                83311              215646
# Education            Bachelors            Bachelors             HS-grad
# Marital-Status   Never-married   Married-civ-spouse            Divorced
# Occupation        Adm-clerical      Exec-managerial   Handlers-cleaners
# Unnamed: 6       Not-in-family              Husband       Not-in-family
# Race                     White                White               White
# Sex                       Male                 Male                Male
# Native-Country   United-States        United-States       United-States
# Salary                   <=50K                <=50K               <=50K
#
#                               3                    4                    5
# ...

# %%
df4=pd.melt(df,id_vars=['Id'],value_vars=['Sex','Race','Native-Country','Education','Workclass','Occupation'])
melted_df_agg = df4.groupby(['Id', 'variable'])['value'].agg(','.join).reset_index()
melted_df_agg
# Out:
#              Id        variable                value
# 0         12285       Education         Some-college
# 1         12285  Native-Country        United-States
# 2         12285      Occupation                    ?
# 3         12285            Race   Amer-Indian-Eskimo
# 4         12285             Sex               Female
# ...         ...             ...                  ...
# 129883  1484705  Native-Country        United-States
# 129884  1484705      Occupation      Exec-managerial
# 129885  1484705            Race                White
# 129886  1484705             Sex               Female
# 129887  1484705       Workclass              Private
#
# [129888 rows x 3 columns]

# %%
df5=melted_df_agg.pivot(index='Id',columns='variable',values='value')
df5
# Out:
# variable      Education  Native-Country          Occupation
# Id
# 12285      Some-college   United-States                   ?  \
# 13769      Some-college   United-States   Machine-op-inspct
# 14878       Prof-school     Philippines      Prof-specialty
# 18827      Some-college   United-States    Transport-moving
# 19214           HS-grad   United-States   Handlers-cleaners
# ...                 ...             ...                 ...
# 1226583       Bachelors   United-States               Sales
# 1268339         HS-grad   United-States        Tech-support
# 1366120       Assoc-voc   United-States       Other-service
# 1455435      Assoc-acdm   United-States        Craft-repair
# 1484705    Some-college   United-States     Exec-managerial
#
# variable                 Race      Sex   Workclass
# Id
# 12285      Amer-Indian-Eskimo   Female           ?
# 13769      Amer-Indian-Eskimo     Male     Private
# 14878      Asian-Pac-Islander     Male   Local-gov
# ...
