# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('../dataset_Facebook.csv', sep=';')
df.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0            139441   Photo         2          12             4          3  \
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions
# 0   0.0                       2752                             5091  \
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers
# ...

# %%
df.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
df['Type'].unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
subset1=df[df['Type']=='Photo']
subset2=df[df['Type']=='Status']
subset3=df[df['Type']=='Video']
subset4=df[df['Type']=='Link']

# %%
print(subset1)
print(subset2)
print(subset3)
print(subset4)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441  Photo         2          12             4          3  \
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
pd.concat([subset1,subset4]).sort_index()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441  Photo         2          12             4          3  \
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
df.sort_values('Page total likes', ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour
# 0              139441   Photo         2          12             4          3  \
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
df1=df.transpose()
df1
# Out:
#                                                        0       1       2
# Page total likes                                    139441  139441  139441  \
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
df_melt=subset1.melt(id_vars=['Type','Category'],var_name='reach',value_name='count')
df_melt
# Out:
#        Type  Category               reach     count
# 0     Photo         2    Page total likes  139441.0
# 1     Photo         3    Page total likes  139441.0
# 2     Photo         2    Page total likes  139441.0
# 3     Photo         2    Page total likes  139441.0
# 4     Photo         3    Page total likes  139441.0
# ...     ...       ...                 ...       ...
# 7237  Photo         3  Total Interactions      84.0
# 7238  Photo         2  Total Interactions      75.0
# 7239  Photo         1  Total Interactions     115.0
# 7240  Photo         3  Total Interactions     136.0
# 7241  Photo         2  Total Interactions     119.0
#
# [7242 rows x 4 columns]

# %%
pivot_table = pd.pivot_table(df_melt,index=['Type'], columns='reach', values='count')
pivot_table
# Out:
# reach  Lifetime Engaged Users
# Type
# Photo              818.946009  \
#
# reach  Lifetime People who have liked your Page and engaged with your post
# Type
# Photo                                         507.305164                    \
#
# reach  Lifetime Post Consumers  Lifetime Post Consumptions
# Type
# Photo               690.431925                 1299.025822  \
#
# reach  Lifetime Post Impressions by people who have liked your Page
# Type
# Photo                                       16422.483568             \
#
# reach  Lifetime Post Total Impressions  Lifetime Post Total Reach
# Type
# Photo                     28994.497653               13137.814554  \
#
# reach  Lifetime Post reach by people who like your Page  Page total likes
# Type
# Photo                                       6059.103286     122354.171362  \
#
# reach  Paid  Post Hour  Post Month  Post Weekday  Total Interactions
# Type
# Photo  0.28   7.997653    6.805164      4.107981          216.579812  \
#
# ...
